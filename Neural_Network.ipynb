# %% [markdown]
# <a href="https://colab.research.google.com/github/june65/Image_Classification/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(loss='mean_squared_error', optimizer='sgd')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 3.6783e-05
# Epoch 2/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.6028e-05
# Epoch 3/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 3.5288e-05
# Epoch 4/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 3.4563e-05
# Epoch 5/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 3.3853e-05
# Epoch 6/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3158e-05
# Epoch 7/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.2477e-05
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1810e-05
# Epoch 9/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1157e-05
# Epoch 10/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0516e-05
# Epoch 11/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9890e-05
# Epoch 12/1000
# ...

# %%
pred = model.predict([5.0])
print(pred)
# Out:
# [[8.995077]]
